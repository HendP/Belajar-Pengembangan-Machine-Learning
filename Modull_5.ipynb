# %% [markdown]
# <a href="https://colab.research.google.com/github/agungtriu/Belajar-Pengembangan-Machine-Learning/blob/master/Modull_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Build dan Train Model untuk Memproses Image Dataset dari Dunia Nyata

# %%
# !wget --no-check-certificate \
  https://dicodingacademy.blob.core.windows.net/picodiploma/ml_pengembangan_academy/Chessman-image-dataset.zip \
  -O /tmp/Chessman-image-dataset.zip
# Out:
# --2020-08-04 12:11:03--  https://dicodingacademy.blob.core.windows.net/picodiploma/ml_pengembangan_academy/Chessman-image-dataset.zip
# Resolving dicodingacademy.blob.core.windows.net (dicodingacademy.blob.core.windows.net)... 52.239.197.36
# Connecting to dicodingacademy.blob.core.windows.net (dicodingacademy.blob.core.windows.net)|52.239.197.36|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 60684125 (58M) [application/zip]
# Saving to: ‘/tmp/Chessman-image-dataset.zip’
#
# /tmp/Chessman-image 100%[===================>]  57.87M  22.8MB/s    in 2.5s
#
# 2020-08-04 12:11:06 (22.8 MB/s) - ‘/tmp/Chessman-image-dataset.zip’ saved [60684125/60684125]

# %%
import os
import zipfile
local_zip = '/tmp/Chessman-image-dataset.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/tmp')
zip_ref.close()

# %%
os.listdir('/tmp/Chessman-image-dataset/Chess')
# Out:
# ['King', 'Bishop', 'Pawn', 'Queen', 'Rook', 'Knight']

# %%
print('total pawn images :', len(os.listdir('/tmp/Chessman-image-dataset/Chess/Pawn')))
print('total King images :', len(os.listdir('/tmp/Chessman-image-dataset/Chess/King')))
print('total Knight images :', len(os.listdir('/tmp/Chessman-image-dataset/Chess/Knight')))
# Out:
# total pawn images : 107
# total King images : 76
# total Knight images : 106

# %%
from keras.preprocessing import image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
img = image.load_img('/tmp/Chessman-image-dataset/Chess/King/00000145.png')
imgplot = plt.imshow(img)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
 
 
train_dir = os.path.join('/tmp/Chessman-image-dataset/Chess')
train_datagen = ImageDataGenerator(rescale=1./255,
    rotation_range=20,
    zoom_range=0.2,
    shear_range=0.2,
    fill_mode = 'nearest',
    validation_split=0.1) # set validation split

# %%
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(150, 150),
    batch_size=8,
    class_mode='categorical',
    subset='training') # set as training data
validation_generator = train_datagen.flow_from_directory(
    train_dir, # same directory as training data
    target_size=(150, 150),
    batch_size=16,
    class_mode='categorical',
    subset='validation')
# Out:
# Found 499 images belonging to 6 classes.
# Found 52 images belonging to 6 classes.

# %%
import tensorflow as tf
model = tf.keras.models.Sequential([
    # Note the input shape is the desired size of the image 150x150 with 3 bytes color
    tf.keras.layers.Conv2D(64, (3,3), activation='relu', input_shape=(150, 150, 3)),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Dropout(0.4),  
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'), 
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Dropout(0.4),  
    # Flatten the results to feed into a DNN
    tf.keras.layers.Flatten(), 
    # 512 neuron hidden layer
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(256, activation='relu'),
    # Only 1 output neuron. It will contain a value from 0-1 where 0 for 1 class ('cats') and 1 for the other ('dogs')
    tf.keras.layers.Dense(6, activation='softmax')  
])

# %%
model.compile(optimizer=tf.optimizers.Adam(),
              loss='categorical_crossentropy',
              metrics = ['accuracy'])

# %%
history = model.fit(train_generator,
                              validation_data=validation_generator,
                              epochs=50,
                              verbose=2)
# Out:
# Epoch 1/50
# 63/63 - 32s - loss: 1.8620 - accuracy: 0.1683 - val_loss: 1.7845 - val_accuracy: 0.1923
# Epoch 2/50
# 63/63 - 31s - loss: 1.7899 - accuracy: 0.1804 - val_loss: 1.7790 - val_accuracy: 0.2115
# Epoch 3/50
# 63/63 - 31s - loss: 1.7797 - accuracy: 0.1723 - val_loss: 1.7680 - val_accuracy: 0.2500
# Epoch 4/50
# 63/63 - 31s - loss: 1.7743 - accuracy: 0.2164 - val_loss: 1.7718 - val_accuracy: 0.1731
# Epoch 5/50
# 63/63 - 31s - loss: 1.7253 - accuracy: 0.2385 - val_loss: 1.7657 - val_accuracy: 0.2500
# Epoch 6/50
# 63/63 - 31s - loss: 1.7195 - accuracy: 0.2725 - val_loss: 1.6970 - val_accuracy: 0.3462
# Epoch 7/50
# 63/63 - 31s - loss: 1.6474 - accuracy: 0.3086 - val_loss: 1.7369 - val_accuracy: 0.3269
# Epoch 8/50
# 63/63 - 31s - loss: 1.6407 - accuracy: 0.3146 - val_loss: 1.6636 - val_accuracy: 0.3269
# Epoch 9/50
# 63/63 - 31s - loss: 1.5988 - accuracy: 0.3808 - val_loss: 1.6849 - val_accuracy: 0.3462
# Epoch 10/50
# 63/63 - 31s - loss: 1.5121 - accuracy: 0.3988 - val_loss: 1.5442 - val_accuracy: 0.4038
# Epoch 11/50
# 63/63 - 31s - loss: 1.5030 - accuracy: 0.3988 - val_loss: 1.6197 - val_accuracy: 0.3269
# Epoch 12/50
# 63/63 - 31s - loss: 1.4749 - accuracy: 0.4168 - val_loss: 1.6227 - val_accuracy: 0.2885
# Epoch 13/50
# 63/63 - 31s - loss: 1.4134 - accuracy: 0.4469 - val_loss: 1.5864 - val_accuracy: 0.3846
# Epoch 14/50
# 63/63 - 31s - loss: 1.3554 - accuracy: 0.4770 - val_loss: 1.5667 - val_accuracy: 0.3462
# Epoch 15/50
# 63/63 - 31s - loss: 1.3256 - accuracy: 0.5090 - val_loss: 1.5850 - val_accuracy: 0.3846
# Epoch 16/50
# 63/63 - 31s - loss: 1.2861 - accuracy: 0.4890 - val_loss: 1.5685 - val_accuracy: 0.3269
# Epoch 17/50
# 63/63 - 31s - loss: 1.2378 - accuracy: 0.5271 - val_loss: 1.5441 - val_accuracy: 0.3846
# Epoch 18/50
# 63/63 - 31s - loss: 1.2830 - accuracy: 0.5110 - val_loss: 1.5209 - val_accuracy: 0.3846
# Epoch 19/50
# 63/63 - 31s - loss: 1.1855 - accuracy: 0.5611 - val_loss: 1.5490 - val_accuracy: 0.3462
# Epoch 20/50
# 63/63 - 31s - loss: 1.1740 - accuracy: 0.5371 - val_loss: 1.5332 - val_accuracy: 0.3846
# Epoch 21/50
# 63/63 - 31s - loss: 1.1186 - accuracy: 0.5351 - val_loss: 1.5544 - val_accuracy: 0.3269
# Epoch 22/50
# 63/63 - 31s - loss: 1.0531 - accuracy: 0.6052 - val_loss: 1.6381 - val_accuracy: 0.2500
# Epoch 23/50
# 63/63 - 31s - loss: 1.0139 - accuracy: 0.6293 - val_loss: 1.4595 - val_accuracy: 0.3654
# Epoch 24/50
# 63/63 - 31s - loss: 0.9457 - accuracy: 0.6333 - val_loss: 1.4842 - val_accuracy: 0.3846
# Epoch 25/50
# 63/63 - 31s - loss: 0.9428 - accuracy: 0.6353 - val_loss: 1.5819 - val_accuracy: 0.3846
# Epoch 26/50
# 63/63 - 31s - loss: 0.8961 - accuracy: 0.6293 - val_loss: 1.5449 - val_accuracy: 0.4038
# Epoch 27/50
# 63/63 - 31s - loss: 0.8451 - accuracy: 0.6854 - val_loss: 1.6542 - val_accuracy: 0.3654
# Epoch 28/50
# 63/63 - 31s - loss: 0.9384 - accuracy: 0.6493 - val_loss: 1.7068 - val_accuracy: 0.3269
# Epoch 29/50
# 63/63 - 31s - loss: 0.8080 - accuracy: 0.7074 - val_loss: 2.1399 - val_accuracy: 0.3077
# Epoch 30/50
# 63/63 - 31s - loss: 0.7919 - accuracy: 0.6994 - val_loss: 1.5860 - val_accuracy: 0.4615
# Epoch 31/50
# 63/63 - 31s - loss: 0.7927 - accuracy: 0.7134 - val_loss: 1.5203 - val_accuracy: 0.4231
# Epoch 32/50
# 63/63 - 31s - loss: 0.6629 - accuracy: 0.7816 - val_loss: 1.8370 - val_accuracy: 0.4231
# Epoch 33/50
# 63/63 - 31s - loss: 0.6936 - accuracy: 0.7315 - val_loss: 2.2540 - val_accuracy: 0.3077
# Epoch 34/50
# 63/63 - 31s - loss: 0.6597 - accuracy: 0.7615 - val_loss: 1.9023 - val_accuracy: 0.4423
# Epoch 35/50
# 63/63 - 31s - loss: 0.6714 - accuracy: 0.7535 - val_loss: 1.5489 - val_accuracy: 0.4231
# Epoch 36/50
# 63/63 - 31s - loss: 0.6969 - accuracy: 0.7375 - val_loss: 1.7259 - val_accuracy: 0.4038
# Epoch 37/50
# 63/63 - 31s - loss: 0.6423 - accuracy: 0.7695 - val_loss: 1.5515 - val_accuracy: 0.5000
# Epoch 38/50
# 63/63 - 31s - loss: 0.6575 - accuracy: 0.7635 - val_loss: 1.6635 - val_accuracy: 0.4038
# Epoch 39/50
# 63/63 - 31s - loss: 0.6372 - accuracy: 0.7695 - val_loss: 1.6889 - val_accuracy: 0.3846
# Epoch 40/50
# 63/63 - 31s - loss: 0.6060 - accuracy: 0.7776 - val_loss: 1.6231 - val_accuracy: 0.3654
# Epoch 41/50
# 63/63 - 31s - loss: 0.5640 - accuracy: 0.8076 - val_loss: 2.1014 - val_accuracy: 0.3654
# Epoch 42/50
# 63/63 - 31s - loss: 0.5344 - accuracy: 0.8337 - val_loss: 1.6692 - val_accuracy: 0.4615
# Epoch 43/50
# 63/63 - 31s - loss: 0.5204 - accuracy: 0.8056 - val_loss: 1.6630 - val_accuracy: 0.4615
# Epoch 44/50
# 63/63 - 31s - loss: 0.5222 - accuracy: 0.8236 - val_loss: 1.5243 - val_accuracy: 0.4231
# Epoch 45/50
# 63/63 - 31s - loss: 0.4655 - accuracy: 0.8176 - val_loss: 2.0230 - val_accuracy: 0.3846
# Epoch 46/50
# 63/63 - 31s - loss: 0.4687 - accuracy: 0.8417 - val_loss: 2.1095 - val_accuracy: 0.4423
# Epoch 47/50
# 63/63 - 31s - loss: 0.4466 - accuracy: 0.8517 - val_loss: 2.5267 - val_accuracy: 0.3846
# Epoch 48/50
# 63/63 - 31s - loss: 0.3641 - accuracy: 0.8597 - val_loss: 1.7659 - val_accuracy: 0.3654
# Epoch 49/50
# 63/63 - 31s - loss: 0.4356 - accuracy: 0.8477 - val_loss: 2.3175 - val_accuracy: 0.4231
# Epoch 50/50
# 63/63 - 31s - loss: 0.3737 - accuracy: 0.8697 - val_loss: 2.1754 - val_accuracy: 0.3654

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Akurasi Model')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss Model')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
